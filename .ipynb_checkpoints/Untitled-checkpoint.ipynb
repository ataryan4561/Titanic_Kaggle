# %%
import pandas as pd
data_frame=pd.read_csv("gender_submission.csv")

# %%
data_frame
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
data_frame2=pd.read_csv("test.csv")
data_frame2
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
data_frame3=pd.read_csv("train.csv")
data_frame3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data_frame3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ladies=data_frame3.loc[data_frame3.Sex=='female']["Survived"]
rate_ladies =sum(ladies)/len(ladies)
rate_ladies
# Out:
# 0.7420382165605095

# %%
mens=data_frame3.loc[data_frame3.Sex=='male']["Survived"]
rate_mens =sum(mens)/len(mens)
rate_mens
# Out:
# 0.18890814558058924

# %%
age_male=data_frame3.loc[data_frame3.Age>29]["Survived"][data_frame3.Sex=='male']
r_age_male=sum(age_male)/len(age_male)
r_age_male
# Out:
# 0.19444444444444445

# %%
age_female=data_frame3.loc[data_frame3.Age>29]["Survived"][data_frame3.Sex=='female']
r_age_female=sum(age_female)/len(age_female)
r_age_female
# Out:
# 0.8070175438596491

# %%
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
data_frame3=data_frame3.drop('SibSp',axis=1)
data_frame3=data_frame3.drop('Parch',axis=1)
data_frame3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
data_frame3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
data_frame3.info()
train_test_data = [data_frame3,data_frame2] 

for dataset in train_test_data:
    dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 69.7+ KB

# %%
train_test_data
# Out:
# [     PassengerId  Survived  Pclass  \
#  0              1         0       3
#  1              2         1       1
#  2              3         1       3
#  3              4         1       1
#  4              5         0       3
#  ..           ...       ...     ...
#  886          887         0       2
#  887          888         1       1
#  888          889         0       3
#  889          890         1       1
#  890          891         0       3
#
#                                                    Name     Sex   Age  \
#  0                              Braund, Mr. Owen Harris    male  22.0
#  1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#  2                               Heikkinen, Miss. Laina  female  26.0
#  3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
#  4                             Allen, Mr. William Henry    male  35.0
#  ..                                                 ...     ...   ...
# ...

# %%
title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 2, 
                 "Master": 3, "Dr": 3, "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3,"Countess": 3,
                 "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3, "Dona" : 3, "Mme": 3,"Capt": 3,"Sir": 3 }
for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].map(title_mapping)

# %%
data_frame3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S      0
# 1          PC 17599  71.2833   C85        C      2
# 2  STON/O2. 3101282   7.9250   NaN        S      1
# 3            113803  53.1000  C123        S      2
# 4            373450   8.0500   NaN        S      0

# %%
data_frame2.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Title
# 0  34.5      0      0   330911   7.8292   NaN        Q      0
# 1  47.0      1      0   363272   7.0000   NaN        S      2
# 2  62.0      0      0   240276   9.6875   NaN        Q      0
# 3  27.0      0      0   315154   8.6625   NaN        S      0
# 4  22.0      1      1  3101298  12.2875   NaN        S      2

# %%
data_frame3.drop('Name', axis=1, inplace=True)
data_frame2.drop('Name', axis=1, inplace=True)

# %%
data_frame3.head(80)
# Out:
#     PassengerId  Survived  Pclass     Sex    Age            Ticket     Fare  \
# 0             1         0       3    male  22.00         A/5 21171   7.2500
# 1             2         1       1  female  38.00          PC 17599  71.2833
# 2             3         1       3  female  26.00  STON/O2. 3101282   7.9250
# 3             4         1       1  female  35.00            113803  53.1000
# 4             5         0       3    male  35.00            373450   8.0500
# ..          ...       ...     ...     ...    ...               ...      ...
# 75           76         0       3    male  25.00            348123   7.6500
# 76           77         0       3    male    NaN            349208   7.8958
# 77           78         0       3    male    NaN            374746   8.0500
# 78           79         1       2    male   0.83            248738  29.0000
# 79           80         1       3  female  30.00            364516  12.4750
#
#     Cabin Embarked  Title
# 0     NaN        S      0
# ...

# %%
data_frame2.head(80)
# Out:
#     PassengerId  Pclass     Sex   Age  SibSp  Parch   Ticket      Fare Cabin  \
# 0           892       3    male  34.5      0      0   330911    7.8292   NaN
# 1           893       3  female  47.0      1      0   363272    7.0000   NaN
# 2           894       2    male  62.0      0      0   240276    9.6875   NaN
# 3           895       3    male  27.0      0      0   315154    8.6625   NaN
# 4           896       3  female  22.0      1      1  3101298   12.2875   NaN
# ..          ...     ...     ...   ...    ...    ...      ...       ...   ...
# 75          967       1    male  32.5      0      0   113503  211.5000  C132
# 76          968       3    male   NaN      0      0   359306    8.0500   NaN
# 77          969       1  female  55.0      2      0    11770   25.7000  C101
# 78          970       2    male  30.0      0      0   248744   13.0000   NaN
# 79          971       3  female  24.0      0      0   368702    7.7500   NaN
#
#    Embarked  Title
# 0         Q      0
# ...

# %%
sex_mapping = {"male": 0, "female": 1}
for dataset in train_test_data:
    dataset['Sex'] = dataset['Sex'].map(sex_mapping)

# %%
train_test_data
# Out:
# [     PassengerId  Survived  Pclass  Sex   Age            Ticket     Fare  \
#  0              1         0       3    0  22.0         A/5 21171   7.2500
#  1              2         1       1    1  38.0          PC 17599  71.2833
#  2              3         1       3    1  26.0  STON/O2. 3101282   7.9250
#  3              4         1       1    1  35.0            113803  53.1000
#  4              5         0       3    0  35.0            373450   8.0500
#  ..           ...       ...     ...  ...   ...               ...      ...
#  886          887         0       2    0  27.0            211536  13.0000
#  887          888         1       1    1  19.0            112053  30.0000
#  888          889         0       3    1   NaN        W./C. 6607  23.4500
#  889          890         1       1    0  26.0            111369  30.0000
#  890          891         0       3    0  32.0            370376   7.7500
#
#      Cabin Embarked  Title
#  0     NaN        S      0
# ...

# %%
data_frame3["Age"].fillna(data_frame3.groupby("Title")["Age"].transform("median"), inplace=True)
data_frame2["Age"].fillna(data_frame2.groupby("Title")["Age"].transform("median"), inplace=True)

# %%
data_frame3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Sex            891 non-null int64
# Age            891 non-null float64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Title          891 non-null int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.7+ KB

# %%
data_frame2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Sex            418 non-null int64
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# Title          418 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 36.0+ KB

# %%
data_frame3=data_frame3.drop('Pclass',axis=1)
data_frame3=data_frame3.drop('Ticket',axis=1)
data_frame3=data_frame3.drop('Fare',axis=1)
data_frame3=data_frame3.drop('Cabin',axis=1)
data_frame3=data_frame3.drop('Embarked',axis=1)
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
# PassengerId    418 non-null int64
# Survived       418 non-null int64
# dtypes: int64(2)
# memory usage: 6.7 KB

# %%
data_frame3.head()
# Out:
#    PassengerId  Survived  Sex   Age  Title
# 0            1         0    0  22.0      0
# 1            2         1    1  38.0      2
# 2            3         1    1  26.0      1
# 3            4         1    1  35.0      2
# 4            5         0    0  35.0      0

# %%
data_frame2.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch   Ticket     Fare Cabin  \
# 0          892       3    0  34.5      0      0   330911   7.8292   NaN
# 1          893       3    1  47.0      1      0   363272   7.0000   NaN
# 2          894       2    0  62.0      0      0   240276   9.6875   NaN
# 3          895       3    0  27.0      0      0   315154   8.6625   NaN
# 4          896       3    1  22.0      1      1  3101298  12.2875   NaN
#
#   Embarked  Title
# 0        Q      0
# 1        S      2
# 2        Q      0
# 3        S      0
# 4        S      2

# %%
data_frame2=data_frame2.drop('Pclass',axis=1)
data_frame2=data_frame2.drop('Ticket',axis=1)
data_frame2=data_frame2.drop('Fare',axis=1)
data_frame2=data_frame2.drop('Cabin',axis=1)
data_frame2=data_frame2.drop('Embarked',axis=1)
data_frame2.head()
# Out:
#    PassengerId  Sex   Age  SibSp  Parch  Title
# 0          892    0  34.5      0      0      0
# 1          893    1  47.0      1      0      2
# 2          894    0  62.0      0      0      0
# 3          895    0  27.0      0      0      0
# 4          896    1  22.0      1      1      2

# %%
data_frame2=data_frame2.drop('SibSp',axis=1)
data_frame2=data_frame2.drop('Parch',axis=1)
data_frame2.head()
# Out:
#    PassengerId  Sex   Age  Title
# 0          892    0  34.5      0
# 1          893    1  47.0      2
# 2          894    0  62.0      0
# 3          895    0  27.0      0
# 4          896    1  22.0      2

# %%
train_test_data
# Out:
# [     PassengerId  Survived  Pclass  Sex   Age            Ticket     Fare  \
#  0              1         0       3    0  22.0         A/5 21171   7.2500
#  1              2         1       1    1  38.0          PC 17599  71.2833
#  2              3         1       3    1  26.0  STON/O2. 3101282   7.9250
#  3              4         1       1    1  35.0            113803  53.1000
#  4              5         0       3    0  35.0            373450   8.0500
#  ..           ...       ...     ...  ...   ...               ...      ...
#  886          887         0       2    0  27.0            211536  13.0000
#  887          888         1       1    1  19.0            112053  30.0000
#  888          889         0       3    1  21.0        W./C. 6607  23.4500
#  889          890         1       1    0  26.0            111369  30.0000
#  890          891         0       3    0  32.0            370376   7.7500
#
#      Cabin Embarked  Title
#  0     NaN        S      0
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
data_frame3_data = data_frame3.drop('Survived', axis=1)
target = data_frame3['Survived']

data_frame3_data.shape, target.shape

clf = SVC()
scoring = 'accuracy'
score = cross_val_score(clf,data_frame3, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# C:\Users\shubh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\shubh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\shubh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
round(np.mean(score)*100, 2)
# Out:
# 61.06

# %%
clf = SVC()
data_frame3=data_frame3.drop('Survived', axis=1)
clf.fit(data_frame3, target)
# Out:
# C:\Users\shubh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
prediction = clf.predict(data_frame2)

# %%
data_frame3.head(80)
# Out:
#     PassengerId  Sex    Age  Title
# 0             1    0  22.00      0
# 1             2    1  38.00      2
# 2             3    1  26.00      1
# 3             4    1  35.00      2
# 4             5    0  35.00      0
# ..          ...  ...    ...    ...
# 75           76    0  25.00      0
# 76           77    0  30.00      0
# 77           78    0  30.00      0
# 78           79    0   0.83      3
# 79           80    1  30.00      1
#
# [80 rows x 4 columns]

# %%
submission = pd.DataFrame({
        "PassengerId": data_frame2["PassengerId"],
        "Survived": prediction
    })

submission.to_csv('submission.csv', index=False)
